# %%
import pandas as pd

# %%
country = 'Egypt'
fer_path = 'Foreign Exchange Reserves USD mn Monthly ' + country + '.csv'
usd = pd.read_csv(fer_path)
fer = usd.iloc[26:]
usd_name = 'Foreign Exchange Reserves: USD mn: Monthly: ' + country
fer.rename(columns={'Unnamed: 0': 'Date', usd_name: 'Foreign Exchange Reserves USD mn'}, inplace = True)
fer['Date'] = pd.to_datetime(fer['Date']) + pd.tseries.offsets.MonthEnd(0)
fer['Foreign Exchange Reserves USD mn'] = fer['Foreign Exchange Reserves USD mn'].astype(float)
# Out:
# C:\Users\MacTavish\AppData\Local\Temp\ipykernel_45724\1578841841.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fer.rename(columns={'Unnamed: 0': 'Date', usd_name: 'Foreign Exchange Reserves USD mn'}, inplace = True)
# C:\Users\MacTavish\AppData\Local\Temp\ipykernel_45724\1578841841.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fer['Date'] = pd.to_datetime(fer['Date']) + pd.tseries.offsets.MonthEnd(0)
# C:\Users\MacTavish\AppData\Local\Temp\ipykernel_45724\1578841841.py:8: SettingWithCopyWarning:
# ...

# %%
fer
# Out:
#           Date  Foreign Exchange Reserves USD mn
# 26  2004-12-31                           13446.7
# 27  2005-01-31                           14662.8
# 28  2005-02-28                           15455.4
# 29  2005-03-31                           16149.2
# 30  2005-04-30                           16589.8
# ..         ...                               ...
# 247 2023-05-31                           24344.4
# 248 2023-06-30                           24713.7
# 249 2023-07-31                           24156.7
# 250 2023-08-31                           24675.4
# 251 2023-09-30                           24934.4
#
# [226 rows x 2 columns]

# %%
from pathlib import Path
parent_dir = str(Path().resolve().parents[1])

# %%
pd.read_csv('/data/GDP/GDP_in_mil_USD_Egypt.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.read_csv('/data/GDP/GDP_in_mil_USD_Egypt.csv')
#
# File c:\Users\MacTavish\.conda\envs\idp\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\MacTavish\.conda\envs\idp\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
for country in ['Egypt', 'Hungary', 'Nigeria', 'Poland', 'Romania']:
    fer_path = 'Foreign Exchange Reserves USD mn Monthly ' + country + '.csv'
    usd = pd.read_csv(fer_path)
    fer = usd.iloc[26:]
    usd_name = 'Foreign Exchange Reserves: USD mn: Monthly: ' + country
    fer.rename(columns={'Unnamed: 0': 'Date', usd_name: 'Foreign Exchange Reserves USD mn'}, inplace = True)
    fer['Date'] = pd.to_datetime(fer['Date']) + pd.tseries.offsets.MonthEnd(0)
    fer['Foreign Exchange Reserves USD mn'] = fer['Foreign Exchange Reserves USD mn'].astype(float)

    csv_path = 'FER_in_mil_USD_' + country + '.csv'
    fer.to_csv(csv_path, index = False)
# Out:
# C:\Users\MacTavish\AppData\Local\Temp\ipykernel_45724\4109282933.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fer.rename(columns={'Unnamed: 0': 'Date', usd_name: 'Foreign Exchange Reserves USD mn'}, inplace = True)
# C:\Users\MacTavish\AppData\Local\Temp\ipykernel_45724\4109282933.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fer['Date'] = pd.to_datetime(fer['Date']) + pd.tseries.offsets.MonthEnd(0)
# C:\Users\MacTavish\AppData\Local\Temp\ipykernel_45724\4109282933.py:8: SettingWithCopyWarning:
# ...
